# %% [markdown]
# # Assignment 1 - Creating and Manipulating Graphs
#
# Eight employees at a small company were asked to choose 3 movies that they would most enjoy watching for the upcoming company movie night. These choices are stored in the file `assets/Employee_Movie_Choices.txt`.
#
# A second file, `assets/Employee_Relationships.txt`, has data on the relationships between different coworkers.
#
# The relationship score has value of `-100` (Enemies) to `+100` (Best Friends). A value of zero means the two employees haven't interacted or are indifferent.
#
# Both files are tab delimited.

# %%
import networkx as nx
import pandas as pd
import numpy as np


# This is the set of employees
employees = set(['Pablo',
                 'Lee',
                 'Georgia',
                 'Vincent',
                 'Andy',
                 'Frida',
                 'Joan',
                 'Claude'])

# This is the set of movies
movies = set(['The Shawshank Redemption',
              'Forrest Gump',
              'The Matrix',
              'Anaconda',
              'The Social Network',
              'The Godfather',
              'Monty Python and the Holy Grail',
              'Snakes on a Plane',
              'Kung Fu Panda',
              'The Dark Knight',
              'Mean Girls'])


# you can use the following function to plot graphs
# make sure to comment it out before submitting to the autograder
def plot_graph(G, weight_name=None):
    '''
    G: a networkx G
    weight_name: name of the attribute for plotting edge weights (if G is weighted)
    '''
    #%matplotlib notebook
    import matplotlib.pyplot as plt
    
    plt.figure()
    pos = nx.spring_layout(G)
    edges = G.edges()
    weights = None
    
    if weight_name:
        weights = [int(G[u][v][weight_name]) for u,v in edges]
        labels = nx.get_edge_attributes(G,weight_name)
        nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
        nx.draw_networkx(G, pos, width=weights)
    else:
        nx.draw_networkx(G, pos,)

# %% [markdown]
# ### Question 1
#
# Using NetworkX, load in the bipartite graph from `assets/Employee_Movie_Choices.txt` and return that graph.
#
# *This function should return a bipartite networkx graph with 19 nodes and 24 edges*

# %%
def answer_one():
    try:
        G1 = nx.read_adjlist('Employee_Movie_Choices.txt', delimiter="\t")
        return G1
    except:
    # YOUR CODE HERE
        raise NotImplementedError()

# %%
assert type(answer_one()) == nx.Graph , "Your return type should be a Graph object"

g = answer_one()
nx.draw(g, with_labels=True)

# %% [markdown]
# ### Question 2
#
# Using the graph from the previous question, add nodes attributes named `'type'` where movies have the value `'movie'` and employees have the value `'employee'` and return that graph.
#
# *This function should return a bipartite networkx graph with node attributes `{'type': 'movie'}` or `{'type': 'employee'}`*

# %%
from networkx.algorithms import bipartite

def answer_two():
    try:
        G1 = answer_one()
        print(bipartite.sets(G1))
        set1, set2 = bipartite.sets(G1)
        for node in set1:
            G1.add_node(node, type='employee')
        for node in set2:
            G1.add_node(node, type='movie')
        return G1
        # YOUR CODE HERE
    except:
        raise NotImplementedError()

g2 = answer_two()
g2.nodes.data()

# Plot the graph for better understanding with labels and colors
nx.draw(g2, with_labels=True, node_color=['blue' if node[1]['type']=='employee' else 'red' for node in g2.nodes(data=True)])
# Out:
# ({'Vincent', 'Claude', 'Georgia', 'Joan', 'Lee', 'Andy', 'Pablo', 'Frida'}, {'Kung Fu Panda', 'The Social Network', 'Mean Girls', 'Snakes on a Plane', 'The Matrix', 'The Shawshank Redemption', 'Monty Python and the Holy Grail', 'The Godfather', 'Forrest Gump', 'The Dark Knight', 'Anaconda'})

# %%
# assert type(answer_two()) == nx.Graph , "Your return type should be a Graph object"

# %% [markdown]
# ### Question 3
#
# Find a weighted projection of the graph from `answer_two` which tells us how many movies different pairs of employees have in common.
#
# *This function should return a weighted projected graph.*

# %%
def answer_three():
    # YOUR CODE HERE
    try:
        G2 = answer_two()
        return bipartite.weighted_projected_graph(G2, employees)

    except:
        raise NotImplementedError()
    
nx.draw(answer_three(), with_labels=True)
# Out:
# ({'Vincent', 'Claude', 'Georgia', 'Joan', 'Lee', 'Andy', 'Pablo', 'Frida'}, {'Kung Fu Panda', 'The Social Network', 'Mean Girls', 'Snakes on a Plane', 'The Matrix', 'The Shawshank Redemption', 'Monty Python and the Holy Grail', 'The Godfather', 'Forrest Gump', 'The Dark Knight', 'Anaconda'})

# %%
G = answer_three()
plot_graph(G, weight_name="weight")
G.edges(data = True)
# Out:
# ({'Vincent', 'Claude', 'Georgia', 'Joan', 'Lee', 'Andy', 'Pablo', 'Frida'}, {'Kung Fu Panda', 'The Social Network', 'Mean Girls', 'Snakes on a Plane', 'The Matrix', 'The Shawshank Redemption', 'Monty Python and the Holy Grail', 'The Godfather', 'Forrest Gump', 'The Dark Knight', 'Anaconda'})
# EdgeDataView([('Vincent', 'Frida', {'weight': 2}), ('Vincent', 'Pablo', {'weight': 1}), ('Claude', 'Andy', {'weight': 1}), ('Claude', 'Georgia', {'weight': 3}), ('Georgia', 'Andy', {'weight': 1}), ('Lee', 'Joan', {'weight': 3}), ('Lee', 'Andy', {'weight': 1}), ('Joan', 'Andy', {'weight': 1}), ('Andy', 'Pablo', {'weight': 1}), ('Andy', 'Frida', {'weight': 1}), ('Pablo', 'Frida', {'weight': 2})])

# %%
assert type(answer_three()) == nx.Graph , "Your return type should be a Graph object"
# Out:
# ({'Vincent', 'Claude', 'Georgia', 'Joan', 'Lee', 'Andy', 'Pablo', 'Frida'}, {'Kung Fu Panda', 'The Social Network', 'Mean Girls', 'Snakes on a Plane', 'The Matrix', 'The Shawshank Redemption', 'Monty Python and the Holy Grail', 'The Godfather', 'Forrest Gump', 'The Dark Knight', 'Anaconda'})

# %% [markdown]
# ### Question 4
#
# Suppose you'd like to find out if people that have a high relationship score also like the same types of movies.
#
# Find the pearson correlation between employee relationship scores and the number of movies they have in common. If two employees have no movies in common it should be treated as a 0, not a missing value, and should be included in the correlation calculation.
#
# *This function should return a float.*

# %%
Relation = nx.read_edgelist('Employee_Relationships.txt', data=[('relationship_score', int)])
Relation

rel_df_2 = pd.read_csv('Employee_Relationships.txt', delimiter="\t", header=None, names=['Employee1', 'Employee2', 'relationship_score'])
rel_df_2
# Out:
#    Employee1 Employee2  relationship_score
# 0       Andy    Claude                   0
# 1       Andy     Frida                  20
# 2       Andy   Georgia                 -10
# 3       Andy      Joan                  30
# 4       Andy       Lee                 -10
# 5       Andy     Pablo                 -10
# 6       Andy   Vincent                  20
# 7     Claude     Frida                   0
# 8     Claude   Georgia                  90
# 9     Claude      Joan                   0
# 10    Claude       Lee                   0
# 11    Claude     Pablo                  10
# 12    Claude   Vincent                   0
# 13     Frida   Georgia                   0
# 14     Frida      Joan                   0
# 15     Frida       Lee                   0
# 16     Frida     Pablo                  50
# 17     Frida   Vincent                  60
# 18   Georgia      Joan                   0
# 19   Georgia       Lee                  10
# 20   Georgia     Pablo                   0
# 21   Georgia   Vincent                   0
# 22      Joan       Lee                  70
# 23      Joan     Pablo                   0
# 24      Joan   Vincent                  10
# 25       Lee     Pablo                   0
# 26       Lee   Vincent                   0
# 27     Pablo   Vincent                 -20

# %%
nx.draw(Relation, with_labels=True)

# %%
Rel_df = pd.DataFrame(Relation.edges(data=True), columns=['From', 'To', 'relationship_score'])
Rel_df['relationship_score'] = Rel_df['relationship_score'].map(lambda x: x['relationship_score'])
Rel_df
# Out:
#        From       To  relationship_score
# 0      Andy   Claude                   0
# 1      Andy    Frida                  20
# 2      Andy  Georgia                 -10
# 3      Andy     Joan                  30
# 4      Andy      Lee                 -10
# 5      Andy    Pablo                 -10
# 6      Andy  Vincent                  20
# 7    Claude    Frida                   0
# 8    Claude  Georgia                  90
# 9    Claude     Joan                   0
# 10   Claude      Lee                   0
# 11   Claude    Pablo                  10
# 12   Claude  Vincent                   0
# 13    Frida  Georgia                   0
# 14    Frida     Joan                   0
# 15    Frida      Lee                   0
# 16    Frida    Pablo                  50
# 17    Frida  Vincent                  60
# 18  Georgia     Joan                   0
# 19  Georgia      Lee                  10
# 20  Georgia    Pablo                   0
# 21  Georgia  Vincent                   0
# 22     Joan      Lee                  70
# 23     Joan    Pablo                   0
# 24     Joan  Vincent                  10
# 25      Lee    Pablo                   0
# 26      Lee  Vincent                   0
# 27    Pablo  Vincent                 -20

# %%
G = answer_three()
G_df = pd.DataFrame(G.edges(data=True), columns=['From', 'To', 'movies_score'])
G_df
# Out:
# ({'Vincent', 'Claude', 'Georgia', 'Joan', 'Lee', 'Andy', 'Pablo', 'Frida'}, {'Kung Fu Panda', 'The Social Network', 'Mean Girls', 'Snakes on a Plane', 'The Matrix', 'The Shawshank Redemption', 'Monty Python and the Holy Grail', 'The Godfather', 'Forrest Gump', 'The Dark Knight', 'Anaconda'})
#        From       To   movies_score
# 0   Vincent    Frida  {'weight': 2}
# 1   Vincent    Pablo  {'weight': 1}
# 2    Claude     Andy  {'weight': 1}
# 3    Claude  Georgia  {'weight': 3}
# 4   Georgia     Andy  {'weight': 1}
# 5       Lee     Joan  {'weight': 3}
# 6       Lee     Andy  {'weight': 1}
# 7      Joan     Andy  {'weight': 1}
# 8      Andy    Pablo  {'weight': 1}
# 9      Andy    Frida  {'weight': 1}
# 10    Pablo    Frida  {'weight': 2}

# %%
#     print (G_df)
G_copy_df = G_df.copy()
#     change the edge direction and get a double direction graph
G_copy_df.rename(columns={"From":"From_", "To":"From"}, inplace=True)
G_copy_df.rename(columns={"From_":"To"}, inplace=True)
#     print (G_copy_df)
G_final_df = pd.concat([G_df, G_copy_df])
#     print (G_final_df)

# %%
G_final_df
# Out:
#        From       To   movies_score
# 0   Vincent    Frida  {'weight': 2}
# 1   Vincent    Pablo  {'weight': 1}
# 2    Claude     Andy  {'weight': 1}
# 3    Claude  Georgia  {'weight': 3}
# 4   Georgia     Andy  {'weight': 1}
# 5       Lee     Joan  {'weight': 3}
# 6       Lee     Andy  {'weight': 1}
# 7      Joan     Andy  {'weight': 1}
# 8      Andy    Pablo  {'weight': 1}
# 9      Andy    Frida  {'weight': 1}
# 10    Pablo    Frida  {'weight': 2}
# 0     Frida  Vincent  {'weight': 2}
# 1     Pablo  Vincent  {'weight': 1}
# 2      Andy   Claude  {'weight': 1}
# 3   Georgia   Claude  {'weight': 3}
# 4      Andy  Georgia  {'weight': 1}
# 5      Joan      Lee  {'weight': 3}
# 6      Andy      Lee  {'weight': 1}
# 7      Andy     Joan  {'weight': 1}
# 8     Pablo     Andy  {'weight': 1}
# 9     Frida     Andy  {'weight': 1}
# 10    Frida    Pablo  {'weight': 2}

# %%
final_df = pd.merge(G_final_df, Rel_df, on = ['From', 'To'], how='right')

# %%
final_df['movies_score'] = final_df['movies_score'].map(lambda x: x['weight'] if type(x)==dict else None)
# final_df['relationship_score'] = final_df['relationship_score'].map(lambda x: x['relationship_score'])
# final_df['movies_score'].fillna(value=0, inplace=True)
final_df
# Out:
#        From       To  movies_score  relationship_score
# 0      Andy   Claude           1.0                   0
# 1      Andy    Frida           1.0                  20
# 2      Andy  Georgia           1.0                 -10
# 3      Andy     Joan           1.0                  30
# 4      Andy      Lee           1.0                 -10
# 5      Andy    Pablo           1.0                 -10
# 6      Andy  Vincent           NaN                  20
# 7    Claude    Frida           NaN                   0
# 8    Claude  Georgia           3.0                  90
# 9    Claude     Joan           NaN                   0
# 10   Claude      Lee           NaN                   0
# 11   Claude    Pablo           NaN                  10
# 12   Claude  Vincent           NaN                   0
# 13    Frida  Georgia           NaN                   0
# 14    Frida     Joan           NaN                   0
# 15    Frida      Lee           NaN                   0
# 16    Frida    Pablo           2.0                  50
# 17    Frida  Vincent           2.0                  60
# 18  Georgia     Joan           NaN                   0
# 19  Georgia      Lee           NaN                  10
# 20  Georgia    Pablo           NaN                   0
# 21  Georgia  Vincent           NaN                   0
# 22     Joan      Lee           3.0                  70
# 23     Joan    Pablo           NaN                   0
# 24     Joan  Vincent           NaN                  10
# 25      Lee    Pablo           NaN                   0
# 26      Lee  Vincent           NaN                   0
# 27    Pablo  Vincent           1.0                 -20

# %%
final_df['movies_score'].fillna(value=0, inplace=True)
# Out:
# /tmp/ipykernel_162124/3717957218.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   final_df['movies_score'].fillna(value=0, inplace=True)

# %%
final_df
# Out:
#        From       To  movies_score  relationship_score
# 0      Andy   Claude           1.0                   0
# 1      Andy    Frida           1.0                  20
# 2      Andy  Georgia           1.0                 -10
# 3      Andy     Joan           1.0                  30
# 4      Andy      Lee           1.0                 -10
# 5      Andy    Pablo           1.0                 -10
# 6      Andy  Vincent           0.0                  20
# 7    Claude    Frida           0.0                   0
# 8    Claude  Georgia           3.0                  90
# 9    Claude     Joan           0.0                   0
# 10   Claude      Lee           0.0                   0
# 11   Claude    Pablo           0.0                  10
# 12   Claude  Vincent           0.0                   0
# 13    Frida  Georgia           0.0                   0
# 14    Frida     Joan           0.0                   0
# 15    Frida      Lee           0.0                   0
# 16    Frida    Pablo           2.0                  50
# 17    Frida  Vincent           2.0                  60
# 18  Georgia     Joan           0.0                   0
# 19  Georgia      Lee           0.0                  10
# 20  Georgia    Pablo           0.0                   0
# 21  Georgia  Vincent           0.0                   0
# 22     Joan      Lee           3.0                  70
# 23     Joan    Pablo           0.0                   0
# 24     Joan  Vincent           0.0                  10
# 25      Lee    Pablo           0.0                   0
# 26      Lee  Vincent           0.0                   0
# 27    Pablo  Vincent           1.0                 -20

# %%
final_df['movies_score'].corr(final_df['relationship_score'])
# Out:
# 0.7883962221733474

# %%
def answer_four():
        
    Rel = nx.read_edgelist('Employee_Relationships.txt', data=[('relationship_score', int)])
    Rel_df = pd.DataFrame(Rel.edges(data=True), columns=['From', 'To', 'relationship_score'])
#     print (Rel_df)
    G = answer_three()
    G_df = pd.DataFrame(G.edges(data=True), columns=['From', 'To', 'movies_score'])
#     print (G_df)
    G_copy_df = G_df.copy()
#     change the edge direction and get a double direction graph
    G_copy_df.rename(columns={"From":"From_", "To":"From"}, inplace=True)
    G_copy_df.rename(columns={"From_":"To"}, inplace=True)
#     print (G_copy_df)
    G_final_df = pd.concat([G_df, G_copy_df])
#     print (G_final_df)
    final_df = pd.merge(G_final_df, Rel_df, on = ['From', 'To'], how='right')
    final_df['movies_score'] = final_df['movies_score'].map(lambda x: x['weight'] if type(x)==dict else None)
    final_df['relationship_score'] = final_df['relationship_score'].map(lambda x: x['relationship_score'])
    final_df['movies_score'].fillna(value=0, inplace=True)
#     print (final_df)

    return final_df['movies_score'].corr(final_df['relationship_score'])

# %%
ans_four = answer_four()
# Out:
# ({'Vincent', 'Claude', 'Georgia', 'Joan', 'Lee', 'Andy', 'Pablo', 'Frida'}, {'Kung Fu Panda', 'The Social Network', 'Mean Girls', 'Snakes on a Plane', 'The Matrix', 'The Shawshank Redemption', 'Monty Python and the Holy Grail', 'The Godfather', 'Forrest Gump', 'The Dark Knight', 'Anaconda'})
# /tmp/ipykernel_162124/1008932282.py:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   final_df['movies_score'].fillna(value=0, inplace=True)

# %%
ans_four
# Out:
# 0.7883962221733474
